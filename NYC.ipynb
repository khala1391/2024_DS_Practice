# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = 'https://github.com/misraturp/Pandas-apply-vs.-map-vs.-applymap/raw/main/NYC_Jobs.csv'
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (3773, 30)

# %%
pd.set_option("display.max_columns", 50)

# %%
pd.get_option("display.max_columns")
# Out:
# 50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Job ID                         3773 non-null   int64
#  1   Agency                         3773 non-null   object
#  2   Posting Type                   3773 non-null   object
#  3   # Of Positions                 3773 non-null   int64
#  4   Business Title                 3773 non-null   object
#  5   Civil Service Title            3773 non-null   object
#  6   Title Classification           3773 non-null   object
#  7   Title Code No                  3773 non-null   object
#  8   Level                          3773 non-null   object
#  9   Job Category                   3771 non-null   object
#  10  Full-Time/Part-Time indicator  3610 non-null   object
#  11  Career Level                   3771 non-null   object
# ...

# %%
df.head(3)
# Out:
#    Job ID                         Agency Posting Type  # Of Positions  \
# 0  424339  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1  379094   NYC EMPLOYEES RETIREMENT SYS     External               1
# 2  520417          NYC HOUSING AUTHORITY     External               1
#
#                                   Business Title       Civil Service Title  \
# 0  Triage Nurse, Bureau of Public Health Clinics       PUBLIC HEALTH NURSE
# 1          CERTIFIED IT DEVELOPER (APPLICATIONS)   CERT IT DEVELOPER (APP)
# 2                            Chief of Settlement  EXECUTIVE AGENCY COUNSEL
#
#   Title Classification Title Code No Level                   Job Category  \
# 0        Competitive-1         51011    03                         Health
# 1        Competitive-1         13643    02  Technology, Data & Innovation
# 2    Non-Competitive-5         95005    M2                  Legal Affairs
#
#   Full-Time/Part-Time indicator               Career Level  Salary Range From  \
# ...
